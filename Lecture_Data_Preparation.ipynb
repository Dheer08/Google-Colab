# %% [markdown]
# <a href="https://colab.research.google.com/github/Dheer08/Google-Colab/blob/main/Lecture_Data_Preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading Libraries
from pandas import read_csv, get_dummies, DataFrame
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Decsriptive Statistics

# %%
data=read_csv('/content/Emloyees.csv')

# %%
data
# Out:
#       Age PastEmployee     BusinessTravel       Department  DistanceFromHome  \
# 0      46           No      Travel_Rarely  Human Resources                 5
# 1      37          Yes      Travel_Rarely  Human Resources                 6
# 2      59           No         Non-Travel  Human Resources                 2
# 3      54           No         Non-Travel  Human Resources                26
# 4      26           No      Travel_Rarely  Human Resources                25
# ...   ...          ...                ...              ...               ...
# 1465   45           No      Travel_Rarely            Sales                20
# 1466   50          Yes      Travel_Rarely            Sales                28
# 1467   39           No      Travel_Rarely            Sales                24
# 1468   26           No      Travel_Rarely            Sales                 5
# 1469   49           No  Travel_Frequently            Sales                 2
#
# ...

# %%
data.describe() # Descriptive Statistics
# Out:
#                Age  DistanceFromHome  EnvironmentSatisfaction  MonthlyIncome  \
# count  1470.000000       1470.000000              1470.000000    1470.000000
# mean     36.923810          9.192517                 2.721769    6502.931293
# std       9.135373          8.106864                 1.093082    4707.956783
# min      18.000000          1.000000                 1.000000    1009.000000
# 25%      30.000000          2.000000                 2.000000    2911.000000
# 50%      36.000000          7.000000                 3.000000    4919.000000
# 75%      43.000000         14.000000                 4.000000    8379.000000
# max      60.000000         29.000000                 4.000000   19999.000000
#
#        NumCompaniesWorked
# count         1470.000000
# mean             2.693197
# std              2.498009
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              4.000000
# max              9.000000

# %%
data.shape # Dimension of the Dataset
# Out:
# (1470, 13)

# %%
data.info() # Description about the data types of columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   PastEmployee             1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   EducationField           1470 non-null   object
#  6   EnvironmentSatisfaction  1470 non-null   int64
#  7   Gender                   1470 non-null   object
#  8   JobRole                  1470 non-null   object
#  9   MaritalStatus            1470 non-null   object
#  10  MonthlyIncome            1470 non-null   int64
#  11  NumCompaniesWorked       1470 non-null   int64
#  12  OverTime                 1470 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 149.4+ KB

# %% [markdown]
# ## Conversion of categorical columns into numeric values

# %% [markdown]
# ### Binary

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   PastEmployee             1470 non-null   object
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   EducationField           1470 non-null   object
#  6   EnvironmentSatisfaction  1470 non-null   int64
#  7   Gender                   1470 non-null   object
#  8   JobRole                  1470 non-null   object
#  9   MaritalStatus            1470 non-null   object
#  10  MonthlyIncome            1470 non-null   int64
#  11  NumCompaniesWorked       1470 non-null   int64
#  12  OverTime                 1470 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 149.4+ KB

# %%
data['PastEmployee'].unique() # Binary
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
data['PastEmployee']=data['PastEmployee'].map({'No':0, 'Yes':1})

# %%
data['PastEmployee']
# Out:
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    1
# 1467    0
# 1468    0
# 1469    0
# Name: PastEmployee, Length: 1470, dtype: int64

# %%
data['Gender'].unique() # Binary
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
data['Gender']=data['Gender'].map({'Male':0, 'Female':1})

# %%
data['OverTime'].unique() # Binary
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['OverTime']=data['OverTime'].map({'No':0, 'Yes':1})

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   PastEmployee             1470 non-null   int64
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   DistanceFromHome         1470 non-null   int64
#  5   EducationField           1470 non-null   object
#  6   EnvironmentSatisfaction  1470 non-null   int64
#  7   Gender                   1470 non-null   int64
#  8   JobRole                  1470 non-null   object
#  9   MaritalStatus            1470 non-null   object
#  10  MonthlyIncome            1470 non-null   int64
#  11  NumCompaniesWorked       1470 non-null   int64
#  12  OverTime                 1470 non-null   int64
# dtypes: int64(8), object(5)
# memory usage: 149.4+ KB

# %% [markdown]
# ### Multiple

# %%
data['BusinessTravel'].unique() # Multiple
# Out:
# array(['Travel_Rarely', 'Non-Travel', 'Travel_Frequently'], dtype=object)

# %%
data['Department'].unique() # Multiple
# Out:
# array(['Human Resources', 'Research & Development', 'Sales'], dtype=object)

# %%
data['EducationField'].unique() # Multiple
# Out:
# array(['Medical', 'Human Resources', 'Life Sciences', 'Technical Degree',
#        'Other', 'Marketing'], dtype=object)

# %%
data['JobRole'].unique() # Multiple
# Out:
# array(['Human Resources', 'Manager', 'Research Scientist',
#        'Laboratory Technician', 'Manufacturing Director',
#        'Healthcare Representative', 'Research Director',
#        'Sales Executive', 'Sales Representative'], dtype=object)

# %%
data['MaritalStatus'].unique() # Multiple
# Out:
# array(['Divorced', 'Married', 'Single'], dtype=object)

# %%
features=['BusinessTravel','Department','EducationField','JobRole','MaritalStatus']
data2=get_dummies(data,columns=features)

# %%
data2.shape
# Out:
# (1470, 32)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                1470 non-null   int64
#  1   PastEmployee                       1470 non-null   int64
#  2   DistanceFromHome                   1470 non-null   int64
#  3   EnvironmentSatisfaction            1470 non-null   int64
#  4   Gender                             1470 non-null   int64
#  5   MonthlyIncome                      1470 non-null   int64
#  6   NumCompaniesWorked                 1470 non-null   int64
#  7   OverTime                           1470 non-null   int64
#  8   BusinessTravel_Non-Travel          1470 non-null   bool
#  9   BusinessTravel_Travel_Frequently   1470 non-null   bool
#  10  BusinessTravel_Travel_Rarely       1470 non-null   bool
# ...

# %%
#data2.to_csv('Data_Prepared')

# %% [markdown]
# ## Seggregation of datset into Dependent and Independent Variable

# %%
Y=data2['PastEmployee'] # Dependent variable
X=data2.drop('PastEmployee',axis=1) # Axis=1 drop column, Independent columns/ dataset

# %%
X.shape
# Out:
# (1470, 31)

# %%
Y.shape
# Out:
# (1470,)

# %% [markdown]
# ## Data scaling

# %%
X_scaled= StandardScaler().fit_transform(X)

# %%
DataFrame(X_scaled)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.993860 -0.517332 -0.660531 -0.816497 -0.314879  2.125136  1.591746
# 1     0.008343 -0.393938  0.254625 -0.816497 -0.941266  0.523316  1.591746
# 2     2.417384 -0.887515  0.254625  1.224745  2.622214  2.525591 -0.628241
# 3     1.869874  2.073946  1.169781  1.224745  2.300096 -0.277594  1.591746
# 4    -1.196177  1.950552  0.254625  1.224745 -0.756622 -0.678049 -0.628241
# ...        ...       ...       ...       ...       ...       ...       ...
# 1465  0.884358  1.333581  1.169781  1.224745 -0.351213  2.125136 -0.628241
# 1466  1.431867  2.320735  1.169781 -0.816497  0.924509  0.523316  1.591746
# 1467  0.227347  1.827158 -0.660531  1.224745  1.174597 -1.078504 -0.628241
# 1468 -1.196177 -0.517332  1.169781  1.224745 -0.751522 -1.078504 -0.628241
# 1469  1.322365 -0.887515  1.169781 -0.816497 -0.236474 -0.277594 -0.628241
#
# ...

# %% [markdown]
# ## Splitting the dataset into Train and Test

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y, test_size = 0.2, random_state = 100)

# %%
X_train.shape
# Out:
# (1176, 31)

# %%
X_test.shape
# Out:
# (294, 31)

# %%
1470-294
# Out:
# 1176

# %% [markdown]
# ## Data balancing

# %%
Y_train.value_counts()
# Out:
# PastEmployee
# 0    987
# 1    189
# Name: count, dtype: int64

# %%
smote=SMOTE(random_state=100)

# %%
X_train, Y_train =smote.fit_resample(X_train, Y_train)

# %%
Y_train.value_counts()
# Out:
# PastEmployee
# 0    987
# 1    987
# Name: count, dtype: int64
